# %%
import pandas as pd
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from wordcloud import WordCloud
import matplotlib.pyplot as plt

df1 = pd.read_excel('output_during(preprocessed).xlsx')

# Step 1: Combine all text data into a single string
text = ' '.join(df1['text'].dropna().tolist())

word_to_drop = 'said'
text = text.replace(word_to_drop, '')

# Step 2: Clean and preprocess the text data
stop_words = set(stopwords.words('english'))
words = word_tokenize(text.lower())
words_cleaned = [str(word) for word in words if word.isalpha() and word not in stop_words]

# Step 3: Generate the word cloud visualization
wordcloud = WordCloud(width=800, height=800, background_color='white').generate(' '.join(words_cleaned))

plt.figure(figsize=(8, 8), facecolor=None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()
plt.savefig('During_wordcloud.png')

# %%
import pandas as pd
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from wordcloud import WordCloud
import matplotlib.pyplot as plt

df2 = pd.read_excel('output_past(preprocessed).xlsx')

# Step 1: Combine all text data into a single string
text = ' '.join(df2['text'].dropna().tolist())

word_to_drop = 'said'
text = text.replace(word_to_drop, '')

# Step 2: Clean and preprocess the text data
stop_words = set(stopwords.words('english'))
words = word_tokenize(text.lower())
words_cleaned = [str(word) for word in words if word.isalpha() and word not in stop_words]

# Step 3: Generate the word cloud visualization
wordcloud = WordCloud(width=800, height=800, background_color='white').generate(' '.join(words_cleaned))

plt.figure(figsize=(8, 8), facecolor=None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()
plt.savefig('Past_wordcloud.png')
